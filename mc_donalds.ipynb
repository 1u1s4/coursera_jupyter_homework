# %%
import pandas as pd

df = pd.read_csv('menu.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plot = sns.jointplot(x='Calories', y='Total Fat', data=df)
plot

# %%
plot = sns.set_style("whitegrid")
ax = sns.boxplot(x=df['Sugars'])
plot

# %%
df.query('Sugars >= 100').sort_values('Sugars', ascending=False)
# Out:
#                Category                                               Item  \
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 246  Smoothies & Shakes                           Strawberry Shake (Large)
# 249  Smoothies & Shakes                            Chocolate Shake (Large)
# 251  Smoothies & Shakes                             Shamrock Shake (Large)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 243  Smoothies & Shakes                              Vanilla Shake (Large)
# 245  Smoothies & Shakes                          Strawberry Shake (Medium)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 253  16.2 oz (460 g)       930                290       33.0
# 246     22 fl oz cup       850                210       24.0
# 249     22 fl oz cup       850                210       23.0
# 251     22 fl oz cup       820                210       23.0
# ...
