# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Luis Alfredo Alvarado Rodríguez

# %% [markdown]
# ## **Objectives:**
# - List popular languages for Data Science
# - List of communly used libraries used by Data Scientist
# - How use tables in markdown
# - Exemples of evaluating arithmetic expressions in Python

# %% [markdown]
# This is a homework for my course of Data Science. Im a student in Coursera.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. C++

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. pandas
# 2. numpy
# 3. scikit-learn

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Python             |
# | Jupyter            |
# | Git                |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
1 + 1
# Out:
# 2

# %%
(23 ** 8) % 5
# Out:
# 1

# %%
7//9
# Out:
# 0

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335
